# %% [markdown]
# # Day 19 Quiz — Mocks
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/19-mocks-quiz.ipynb)
#
# > 🎯 **What this tests.** monkeypatch, MagicMock, unittest.mock.patch, when to mock, assert_called_with.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** Why mock external dependencies in tests?

# %% [markdown]
# **A2.** Where does monkeypatch revert changes?

# %% [markdown]
# **A3.** What's MagicMock useful for?

# %% [markdown]
# **A4.** Patch path rule:

# %% [markdown]
# **A5.** What does `mock.assert_called_once()` do?

# %% [markdown]
# **A6.** When NOT to mock?

# %% [markdown]
# **A7.** What's a 'flaky' test?

# %% [markdown]
# **A8.** What does `MagicMock().json.return_value = []` do?

# %% [markdown]
# **A9.** Should you mock your own classes?

# %% [markdown]
# **A10.** Sign you're over-mocking?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
from unittest.mock import MagicMock
m = MagicMock()
m.x.y.z = 5
print(m.x.y.z)

# %% [markdown]
# **B2.**

# %%
from unittest.mock import MagicMock
m = MagicMock()
print(m())  # calling it
print(m())
print(m.call_count)

# %% [markdown]
# **B3.**

# %%
from unittest.mock import MagicMock
m = MagicMock(return_value=42)
print(m('any', 'args'))

# %% [markdown]
# **B4.**

# %%
from unittest.mock import MagicMock
m = MagicMock()
m.json.return_value = [1, 2]
print(m.json())

# %% [markdown]
# **B5.**

# %%
from unittest.mock import MagicMock
m = MagicMock()
m('hello')
m.assert_called_with('hello')

# %% [markdown]
# **B6.**

# %%
from unittest.mock import MagicMock
m = MagicMock()
m('hello')
try:
    m.assert_called_with('world')
except AssertionError as e:
    print('caught')

# %% [markdown]
# **B7.**

# %%
from unittest.mock import patch
import some_module
with patch('some_module.f') as mock:
    mock.return_value = 1
    some_module.f(99)
print(some_module.f)

# %% [markdown]
# **B8.**

# %%
from unittest.mock import MagicMock
m = MagicMock(side_effect=ValueError('boom'))
m()

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** monkeypatch `requests.get` to return a fake response.

# %%
def test_fetch(monkeypatch):
    class FakeResp:
        status_code = 200
        def json(self): return [{'word': 'cat'}]
    ???

# %% [markdown]
# **C2.** Configure a MagicMock to return a specific dict from .json().

# %%
from unittest.mock import MagicMock
fake_get = MagicMock()
???

# %% [markdown]
# **C3.** Patch decorator.

# %%
from unittest.mock import patch
@patch('english_helper.api.requests.get')
def test_x(???):
    ???.return_value.status_code = 200

# %% [markdown]
# **C4.** Verify a mock was called exactly once.

# %%
mock.???

# %% [markdown]
# **C5.** Make a mock raise on call.

# %%
from unittest.mock import MagicMock
m = MagicMock(???)

# %% [markdown]
# **C6.** Patch `datetime.now()` to return a fixed time.

# %%
from unittest.mock import patch
from datetime import datetime
fixed = datetime(2026, 1, 1)
@patch('english_helper.scheduler.datetime')
def test_review(mock_dt):
    ???

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
from unittest.mock import patch
@patch('requests.get')   # patching the original module
def test_fetch(mock_get):
    mock_get.return_value.status_code = 200
    api.fetch_word('cat')  # api module still uses original requests

# %% [markdown]
# **D2.**

# %%
from unittest.mock import MagicMock
fake = MagicMock()
fake.status_code = 404  # set attribute
fake.json = []  # set attribute, NOT return value

# %% [markdown]
# **D3.**

# %%
from unittest.mock import patch
with patch('api.fetch_word') as mock:
    mock.return_value = {'word': 'cat'}
# After with-block:
print(mock.call_count)

# %% [markdown]
# **D4.**

# %%
from unittest.mock import MagicMock
m = MagicMock(return_value=42)
m.return_value = 99
print(m())

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Mock `requests.get` for 200 success.

# %%
# Your test

# %% [markdown]
# **E2.** Mock for 404.

# %%
# Your test

# %% [markdown]
# **E3.** Mock for Timeout exception.

# %%
# Your test

# %% [markdown]
# **E4.** Verify the URL the mock was called with.

# %%
# Your test

# %% [markdown]
# **E5.** Test `extract_ipa` with a fixture — NO mock needed (pure function).

# %%
# Your test + fixture

# %% [markdown]
# **E6.** Mock `random.choice` for deterministic quiz tests.

# %%
# Your test

# %% [markdown]
# **E7.** Mock `datetime.now` for deterministic spaced-repetition tests.

# %%
# Your test (this one's trickier)

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
