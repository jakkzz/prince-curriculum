# %% [markdown]
# # Day 1 — Hello, Python
#
# > ⚠️ **Why this matters.** Python is the world's most-used programming language. NASA uses it, Netflix uses it, Instagram is built on it, and the AI revolution runs on it. You're about to write your first Python, and from this moment forward, every problem you've ever seen and shrugged at — "oh someone else can do that" — becomes something you can take a swing at.
#
#
# 🇹🇭 *Python คือภาษาที่คนใช้กันมากที่สุดในโลก — NASA ใช้ Netflix ใช้ Instagram สร้างด้วย Python ทุก AI ที่กำลังเปลี่ยนโลกตอนนี้รันบน Python วันนี้เขียน Python ครั้งแรก — ปัญหาที่เคยเห็นแล้วคิดว่า 'คนอื่นทำแหละ' จะเปลี่ยนเป็นปัญหาที่ลองทำเองได้*
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/01-hello-python.ipynb)
#
# ## What you'll do today
#
# **Time:** 90 minutes.
#
# By the end:
#
# - [ ] You've run your first Python expressions in a notebook
# - [ ] You can use the Python REPL
# - [ ] You understand the difference between an expression and a statement
# - [ ] You can read a Python error message
# - [ ] You've written and run your first `.py` file with `uv run`
#
# ## The mental model
#
# Python is a conversation, like the shell. You ask it to evaluate something. It evaluates. It tells you what it got.
#
# ```
# you:    2 + 2
# python: 4
# ```
#
# That's the entire programming language. Everything else — variables, functions, classes, libraries — is just dressing on top of *evaluate this thing, give me back the answer*.
#
# > 💡 **In the wild:** Every data scientist at every tech company spends a huge fraction of their day in Jupyter notebooks like this one. The flow — type, run, see, refine — is *the* iteration loop for exploratory programming. You're learning it on Day 1 because it's the right tool, not the toy tool.

# %% [markdown]
# ## 1. Your first cell — run this
#
# Click on the cell below. Press `Shift + Enter` (or click the ▶ button) to run it.

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# `Shift+Enter` = run this cell, move to next. `Cmd+Enter` (Mac) / `Ctrl+Enter` (Windows) = run, stay here.
#
# Notebooks show the last expression's value automatically. No `print()` needed when you just want to see what something evaluates to.

# %% [markdown]
# ## 2. Variables
#
# A variable is a name attached to a value. The `=` is not "equals" — it's "this name now refers to this value."

# %%
age = 16
age
# Out:
# 16

# %%
next_year = age + 1
next_year
# Out:
# 17

# %% [markdown]
# > ⚠️ **One name per concept.** Don't reuse `age` to mean different things in different places. Read your future self's code: `age` should always mean age. If you have a new concept, give it a new name.

# %% [markdown]
# ## 3. Strings — and the magic of f-strings
#
# Strings are text, wrapped in quotes. Double or single, your choice — be consistent.

# %%
name = "Prince"
greeting = "Hello, " + name + "!"
greeting
# Out:
# 'Hello, Prince!'

# %% [markdown]
# That `+` concatenation works but it's ugly. The modern way is an **f-string** — an `f` before the quote lets you embed expressions inside `{}`:

# %%
f"Hello, {name}! Next year you will be {age + 1}."
# Out:
# 'Hello, Prince! Next year you will be 17.'

# %% [markdown]
# **Try it:** Change the cell above to print your real name and your real age. Re-run.

# %% [markdown]
# ## 4. Expression vs statement
#
# This trips up beginners. Memorize it now.
#
# - **Expression** = code that *produces a value*. `2 + 2`, `len("hello")`, `name.upper()`.
# - **Statement** = code that *does something*. `name = "Prince"`, `if x: ...`, `print(x)`.
#
# An expression can be on the right side of `=`. A statement cannot.
#
# Notebooks show the value of the **last expression** in a cell. They don't show anything for statements unless you explicitly print.

# %%
x = 5         # statement — assigns 5 to x, no output

# %%
x             # expression — produces 5
# Out:
# 5

# %%
print(x)      # statement — does something (prints) but has no output value
# Out:
# 5

# %% [markdown]
# Notice the difference: the bare `x` cell showed `5` as the *result* (in `Out[]`). The `print(x)` cell showed `5` as *output stream* (no `Out[]`).
#
# It's subtle but it matters when you start writing functions.

# %% [markdown]
# ## 5. Numbers — int vs float
#
# Python has two kinds of numbers:
#
# - `int` — whole numbers. No size limit. `42`, `-7`, `1_000_000` (underscores for readability).
# - `float` — decimals. IEEE 754, so imprecise. `3.14`, `-0.5`, `1.0`.
#
# **Math operators:**
#
# | Operator | Meaning | Example |
# |----------|---------|---------|
# | `+`      | add | `2 + 3` → `5` |
# | `-`      | subtract | `7 - 4` → `3` |
# | `*`      | multiply | `2 * 3` → `6` |
# | `/`      | divide (always float) | `7 / 2` → `3.5` |
# | `//`     | floor divide (integer result) | `7 // 2` → `3` |
# | `%`      | modulo (remainder) | `7 % 2` → `1` |
# | `**`     | exponent | `2 ** 10` → `1024` |
#
# Run each below:

# %%
7 / 2     # always returns a float, even when result is whole
# Out:
# 3.5

# %%
7 // 2    # floor division — drops the remainder
# Out:
# 3

# %%
0.1 + 0.2    # this is not 0.3 — welcome to floating point
# Out:
# 0.30000000000000004

# %% [markdown]
# > ⚠️ **Float weirdness is real.** `0.1 + 0.2 != 0.3`. This isn't a Python bug — it's how computers represent decimals in binary. When you need exact decimals (money!), use the `Decimal` type. For everything else, just be aware.

# %% [markdown]
# ## 6. Reading error messages
#
# You will get errors. Reading the error is half the battle. Most beginners scan past them; senior engineers read them carefully.
#
# **Run the cell below.** It will error on purpose. Don't panic — read the message.

# %%
5 + "hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 5 + "hello"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Read the error from bottom to top:
#
# 1. **The bottom line is the actual error:** `TypeError: unsupported operand type(s) for +: 'int' and 'str'`. Translation: "I don't know how to `+` a number and a text."
# 2. **The line above shows where:** Cell In[12], line 1.
# 3. **The arrow `--->`** points to the offending line.
#
# Errors are the language being **honest** with you. They tell you what's wrong, where, and often hint at how to fix it. The fix here is: convert the number to a string first.
#
# **Try it:** Modify the cell to be `str(5) + " hello"`. Re-run. Now it works.

# %% [markdown]
# ## 7. From notebook to script
#
# Notebooks are great for exploration. But your tools need to live in `.py` files so you can run them from a terminal, share them, and put them on GitHub.
#
# Same Python. Different container. The notebook is the scratch pad; the `.py` file is the deliverable.
#
# Open your terminal:
#
# ```bash
# cd ~/prince/scratch
# uv init english-helper
# cd english-helper
# ```
#
# You'll do the rest in the mini-project below.

# %% [markdown]
# ## End-of-day mini-project — `vocab_card.py`
#
# > 🎯 **This is the first piece of the [English Helper running project](RUNNING-PROJECT.md).** Today's piece: print a single, formatted vocabulary flashcard. Each day you'll add a new piece. By Phase 1's end you'll have a real CLI tool you actually use to study English.
#
# ### What you're building
#
# A Python script that prints a flashcard like this for an English word:
#
# ```
# ================================
#   ENGLISH: ubiquitous
#    THAI:   พบเห็นได้ทั่วไป
#    POS:    adjective
# ================================
# "Smartphones have become ubiquitous in modern life."
# ================================
# ```
#
# ### Steps
#
# 1. In your terminal:
#
#    ```bash
#    cd ~/prince/scratch/english-helper
#    code vocab_card.py    # opens the file in VS Code (empty)
#    ```
#
# 2. Write `vocab_card.py` so it prints a flashcard for any word you pick. **Use only what you learned today** — variables, f-strings, math (`"=" * 32` gives you the border), no functions yet (we'll learn those Day 4).
#
# 3. Run it:
#
#    ```bash
#    uv run python vocab_card.py
#    ```
#
# 4. Edit the word, run it again. Pick a real English word you don't know yet — write its Thai meaning, find the part of speech, and write a sentence.
#
# ### Constraints
#
# - All four "borders" must be the same width. (Hint: store the width in a variable, use `"=" * width`.)
# - The labels (`ENGLISH:`, `THAI:`, `POS:`) should align. Pad with spaces.
# - Use f-strings, not `+` concatenation.
#
# ### Try it before peeking at the answer

# %%
# Write your code here and test it. Then copy to vocab_card.py.
word = "ubiquitous"
thai = "พบเห็นได้ทั่วไป"
pos = "adjective"
sentence = "Smartphones have become ubiquitous in modern life."

# Your code here

# %% [markdown]
# <details>
# <summary>Solution — try first!</summary>
#
# ```python
# # vocab_card.py
# word = "ubiquitous"
# thai = "พบเห็นได้ทั่วไป"
# pos = "adjective"
# sentence = "Smartphones have become ubiquitous in modern life."
#
# width = 32
# border = "=" * width
#
# print(border)
# print(f"  ENGLISH: {word}")
# print(f"   THAI:   {thai}")
# print(f"   POS:    {pos}")
# print(border)
# print(f'"{sentence}"')
# print(border)
# ```
#
# **Stretch (try after the basic version works):**
# - Use `input()` to ask the user for the word, thai, pos, and sentence. Print the card from their input.
# - Center the border using `"english helper".center(width, "=")`.
# - Add a date stamp at the bottom: `from datetime import date; print(date.today())`.
# </details>

# %% [markdown]
# ## Connect to the project
#
# > 🎯 **Connects to the project:** You just shipped Day 1 of the English Helper tool. Every day this week adds one more piece. By Friday you'll have an interactive vocabulary quiz running entirely from your laptop, no internet needed.
#
# Then in Week 2 you'll learn the `requests` library and your tool will start pulling **real definitions from a real dictionary API** — typing a word and getting its actual IPA pronunciation and example sentences from a database that linguistic professionals built.
#
# ## Self-check
#
# <details>
# <summary>1. What does <code>=</code> mean in Python?</summary>
#
# Assignment, not equality. `age = 16` means "the name `age` now refers to the value `16`." Test equality with `==`.
# </details>
#
# <details>
# <summary>2. What's the difference between an expression and a statement?</summary>
#
# An expression *evaluates* to a value (`2 + 2`, `name`, `f"hi {name}"`). A statement *does* something (`name = "Prince"`, `print(x)`, `if x: ...`). Expressions can be on the right of `=`; statements can't.
# </details>
#
# <details>
# <summary>3. Why does <code>0.1 + 0.2</code> not equal <code>0.3</code> in Python?</summary>
#
# Floats are stored in binary IEEE 754 format. Some decimals don't have exact binary representations. `0.1 + 0.2` is actually `0.30000000000000004`. For money or exact decimals, use `decimal.Decimal`.
# </details>
#
# <details>
# <summary>4. What does this error mean? <code>TypeError: unsupported operand type(s) for +: 'int' and 'str'</code></summary>
#
# You tried to `+` a number and a string. Python won't auto-convert. Wrap the number with `str()` or the string with `int()`, whichever makes sense.
# </details>
#
# <details>
# <summary>5. How is a Jupyter notebook different from a <code>.py</code> file?</summary>
#
# Notebooks are interactive — cells run one at a time, state persists between cells, results display inline. Great for exploration. `.py` files are scripts — run top to bottom, no inline output, deploys to production. You'll use both: notebooks to try things, scripts to ship them.
# </details>
#
# ## What's next
#
# Tomorrow: **types and values** in depth. You'll learn type hints and turn your single vocab card into a typed list of words — the next piece of English Helper.
#
# **Don't forget the quiz!** Open [01-hello-python-quiz.ipynb](01-hello-python-quiz.ipynb) for 30+ questions to confirm you've absorbed today's lesson before moving on.
