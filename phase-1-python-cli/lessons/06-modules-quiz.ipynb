# %% [markdown]
# # Day 6 Quiz — Modules & Project Structure
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/06-modules-quiz.ipynb)
#
# > 🎯 **What this tests.** Modules, packages, `import` forms, `__name__ == '__main__'`, src layout.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** What's a module?

# %% [markdown]
# **A2.** What makes a folder a package?

# %% [markdown]
# **A3.** Which import is more Pythonic for one-off use?

# %% [markdown]
# **A4.** What's `if __name__ == '__main__':` for?

# %% [markdown]
# **A5.** Why is `english-helper` a bad module name?

# %% [markdown]
# **A6.** What does `from package import module` do?

# %% [markdown]
# **A7.** Which goes in `tests/` (not in `src/`)?

# %% [markdown]
# **A8.** What's a relative import?

# %% [markdown]
# **A9.** Where does Python look for modules?

# %% [markdown]
# **A10.** What does `python -m english_helper.cli` do?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.** What does this print?

# %%
import math
print(math.pi)

# %% [markdown]
# **B2.** What does this print?

# %%
from math import pi
print(pi)

# %% [markdown]
# **B3.** What's `__name__` here?

# %%
# In a file run as `python this_file.py`:
print(__name__)

# %% [markdown]
# **B4.** What's `__name__` here?

# %%
# In dictionary.py, when imported by another module:
# print(__name__)
# What would print?

# %% [markdown]
# **B5.**

# %%
# config.py:
MAX_USERS = 100

# main.py:
from config import MAX_USERS
print(MAX_USERS * 2)

# %% [markdown]
# **B6.**

# %%
import os
print(os.path.join('users', 'prince', 'docs'))

# %% [markdown]
# **B7.**

# %%
from pathlib import Path
print(Path.home())

# %% [markdown]
# **B8.**

# %%
# pkg/__init__.py:
MESSAGE = 'hello'

# elsewhere:
import pkg
print(pkg.MESSAGE)

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Import `json` and use it to parse a string.

# %%
??? 
data = json.loads('{"x": 1}')
print(data)

# %% [markdown]
# **C2.** Import just `Path` from `pathlib`.

# %%
??? 
p = Path.home() / 'prince'
print(p)

# %% [markdown]
# **C3.** Add the standard `if __name__` guard.

# %%
def main():
    print('hi')

???

# %% [markdown]
# **C4.** Set up the import for english-helper's dictionary module.

# %%
??? 
result = lookup(words, 'thorough')

# %% [markdown]
# **C5.** Write a relative import from a sibling module.

# %%
# In src/english_helper/cli.py, importing from storage.py in same package:
???

# %% [markdown]
# **C6.** Make the `english_helper` package runnable via `python -m english_helper`.

# %%
# What file do you create, and what does it contain?

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
from json loads

# %% [markdown]
# **D2.**

# %%
import english-helper
print(english-helper.lookup('thorough'))

# %% [markdown]
# **D3.**

# %%
# Module structure issue:
# english_helper/
#   dictionary.py
# vocab_app.py    ← OUTSIDE the package
#
# In vocab_app.py:
from .dictionary import lookup

# %% [markdown]
# **D4.**

# %%
# circular import:
# a.py: from b import foo
# b.py: from a import bar

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Restructure your english-helper into the src layout. Show the resulting folder tree.

# %%
# In your terminal — sketch the tree here

# %% [markdown]
# **E2.** Write the imports for a new `quiz.py` module that uses `lookup` from `dictionary.py` and `load` from `storage.py`.

# %%
# src/english_helper/quiz.py
???

# %% [markdown]
# **E3.** In `__init__.py`, expose `lookup`, `load`, and `save` as the package's public API.

# %%
# src/english_helper/__init__.py
???

# %% [markdown]
# **E4.** Write a `__main__.py` that runs the CLI when `python -m english_helper` is invoked.

# %%
# src/english_helper/__main__.py
???

# %% [markdown]
# **E5.** Update pyproject.toml to expose `english-helper` as a CLI command via entry points.

# %%
# pyproject.toml — add an entry point
???

# %% [markdown]
# **E6.** Write a relative import for `dictionary.py` in a test file `tests/test_dictionary.py`.

# %%
# tests/test_dictionary.py
???

# %% [markdown]
# **E7.** Refactor: move the `load` and `save` functions out of `cli.py` into a new `storage.py` module. Update imports.

# %%
# Show the resulting cli.py imports

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
