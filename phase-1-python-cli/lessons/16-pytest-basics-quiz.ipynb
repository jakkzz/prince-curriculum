# %% [markdown]
# # Day 16 Quiz — pytest Basics
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/16-pytest-basics-quiz.ipynb)
#
# > 🎯 **What this tests.** Writing tests, `assert`, `pytest.raises`, `parametrize`, project structure, pytest CLI flags.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** What does `assert` do?

# %% [markdown]
# **A2.** Which file names will pytest auto-discover?

# %% [markdown]
# **A3.** What's `with pytest.raises(ValueError):`?

# %% [markdown]
# **A4.** What's @parametrize for?

# %% [markdown]
# **A5.** What's `tmp_path` fixture?

# %% [markdown]
# **A6.** Where should tests live in a src-layout project?

# %% [markdown]
# **A7.** What does `pytest -x` do?

# %% [markdown]
# **A8.** Why one test file per source module?

# %% [markdown]
# **A9.** Best way to test serialization roundtrip?

# %% [markdown]
# **A10.** Why use `pytest -v` during dev?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
def test_a(): assert 1 + 1 == 2

# %% [markdown]
# **B2.**

# %%
def test_a(): assert 1 + 1 == 3

# %% [markdown]
# **B3.**

# %%
import pytest
def test_a():
    with pytest.raises(ValueError):
        int('hello')

# %% [markdown]
# **B4.**

# %%
import pytest
def test_a():
    with pytest.raises(ValueError):
        int('42')

# %% [markdown]
# **B5.**

# %%
import pytest
@pytest.mark.parametrize('a,b,expected', [(1, 2, 3), (5, 5, 10)])
def test_add(a, b, expected):
    assert a + b == expected

# %% [markdown]
# **B6.**

# %%
def test_division():
    assert 10 / 2 == 5

# %% [markdown]
# **B7.**

# %%
def test_list():
    xs = [1, 2, 3]
    xs.append(4)
    assert xs == [1, 2, 3, 4]

# %% [markdown]
# **B8.**

# %%
def test_tmp(tmp_path):
    p = tmp_path / 'a.txt'
    p.write_text('hello')
    assert p.read_text() == 'hello'

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Test that 1 + 1 equals 2.

# %%
def test_add():
    ???

# %% [markdown]
# **C2.** Test that `int('not a number')` raises ValueError.

# %%
import pytest
def test_int_invalid():
    ???

# %% [markdown]
# **C3.** Parametrize with 3 inputs.

# %%
import pytest
???
def test_square(x, expected):
    assert x ** 2 == expected

# %% [markdown]
# **C4.** Use tmp_path to test file writing.

# %%
def test_write(tmp_path):
    ???

# %% [markdown]
# **C5.** Test that a Word is equal to itself reconstructed via to_dict/from_dict.

# %%
from english_helper.word import Word
def test_word_roundtrip():
    ???

# %% [markdown]
# **C6.** Test that an empty WordStore returns None for lookup.

# %%
from english_helper.storage import WordStore
def test_empty_lookup():
    ???

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
def test_a():
    assert 1 + 1 == 3  # will fail

# %% [markdown]
# **D2.**

# %%
def divide(a, b): return a / b
def test_divide():
    assert divide(10, 0) == 0  # ZeroDivisionError before assert checks

# %% [markdown]
# **D3.**

# %%
def add_word_test():  # missing test_ prefix
    assert 1 == 1

# %% [markdown]
# **D4.**

# %%
def test_dict_in_set():
    assert {1: 'a'} == {1: 'a'}  # passes
    assert {{1: 'a'}, {2: 'b'}}  # TypeError

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Test Word creation with defaults.

# %%
from english_helper.word import Word
# Your test

# %% [markdown]
# **E2.** Test Word equality across instances.

# %%
# Your test

# %% [markdown]
# **E3.** Parametrize test of word.is_long property.

# %%
# Your test

# %% [markdown]
# **E4.** Test that adding a word makes it findable.

# %%
from english_helper.storage import WordStore
# Your test

# %% [markdown]
# **E5.** Test save & load round-trip using tmp_path.

# %%
# Your test

# %% [markdown]
# **E6.** Test that strict_lookup raises WordNotFoundError on missing word.

# %%
import pytest
from english_helper.dictionary import strict_lookup, WordNotFoundError
# Your test

# %% [markdown]
# **E7.** Test a quiz mode grades correctly.

# %%
from english_helper.quiz_modes import RandomQuiz
from english_helper.word import Word
# Your test

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
