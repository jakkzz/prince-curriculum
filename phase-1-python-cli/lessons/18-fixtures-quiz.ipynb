# %% [markdown]
# # Day 18 Quiz — Fixtures
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/18-fixtures-quiz.ipynb)
#
# > 🎯 **What this tests.** `@pytest.fixture`, fixture composition, scopes, conftest.py, built-in fixtures.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** What's a pytest fixture?

# %% [markdown]
# **A2.** Default fixture scope?

# %% [markdown]
# **A3.** Where do shared fixtures go?

# %% [markdown]
# **A4.** What does `tmp_path` give you?

# %% [markdown]
# **A5.** When use `scope='session'`?

# %% [markdown]
# **A6.** What does `capsys` give you?

# %% [markdown]
# **A7.** Can a fixture depend on another fixture?

# %% [markdown]
# **A8.** What's `monkeypatch` for?

# %% [markdown]
# **A9.** Why prefer function scope?

# %% [markdown]
# **A10.** A test takes parameter `empty_store`. Where does the value come from?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
import pytest
@pytest.fixture
def five():
    return 5

def test_use(five):
    assert five == 5

# %% [markdown]
# **B2.**

# %%
import pytest
class C: count = 0

@pytest.fixture
def c():
    C.count += 1
    return C.count

def test_a(c): pass
def test_b(c): pass
print(C.count)

# %% [markdown]
# **B3.**

# %%
import pytest
@pytest.fixture(scope='module')
def big():
    print('SETUP')
    return 42

def test_a(big): pass
def test_b(big): pass

# %% [markdown]
# **B4.**

# %%
import pytest
@pytest.fixture
def store():
    return {'x': 1}

def test_mutates(store):
    store['x'] = 99

def test_clean(store):
    assert store['x'] == 1

# %% [markdown]
# **B5.**

# %%
import pytest
@pytest.fixture
def base(): return 10
@pytest.fixture
def double(base): return base * 2
def test(double): assert double == 20

# %% [markdown]
# **B6.**

# %%
def test_print(capsys):
    print('hello')
    captured = capsys.readouterr()
    assert captured.out == 'hello\n'

# %% [markdown]
# **B7.**

# %%
def test_file(tmp_path):
    f = tmp_path / 'a.txt'
    f.write_text('hi')
    assert f.exists()

# %% [markdown]
# **B8.**

# %%
import pytest
@pytest.fixture
def bad():
    1/0

def test_use(bad): pass

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Define a fixture `name` returning 'Prince'.

# %%
import pytest
???

# %% [markdown]
# **C2.** Use the fixture in a test.

# %%
def test_greet(???):
    assert ??? == 'Prince'

# %% [markdown]
# **C3.** Fixture composition: `account` uses `name`.

# %%
@pytest.fixture
def name(): return 'Prince'
@pytest.fixture
def account(???): 
    return {'owner': name}

# %% [markdown]
# **C4.** Module-scoped expensive fixture.

# %%
@pytest.fixture(???)
def expensive():
    return load_dataset()

# %% [markdown]
# **C5.** Test that uses tmp_path to write/read a file.

# %%
def test_write(tmp_path):
    p = tmp_path / 'x.txt'
    ???

# %% [markdown]
# **C6.** Use monkeypatch to set env var.

# %%
def test_env(monkeypatch):
    ???
    import os
    assert os.environ['DEBUG'] == '1'

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
import pytest
@pytest.fixture
def data(): return [1, 2, 3]

def test_mutate(data):
    data.append(4)

def test_clean(data):
    assert data == [1, 2, 3]

# %% [markdown]
# **D2.**

# %%
import pytest
@pytest.fixture
def base(): return 5
def test_use():  # forgot to take base as param
    assert base == 5

# %% [markdown]
# **D3.**

# %%
# tests/conftest.py
import pytest
from english_helper.storage import WordStore
@pytest.fixture
def store(): return WordStore()

# tests/test_x.py
from conftest import store  # wrong

# %% [markdown]
# **D4.**

# %%
import pytest
@pytest.fixture(scope='session')
def db():
    conn = connect()
    return conn
# every test mutates db

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** conftest.py with empty_store, sample_words, store_with_words.

# %%
# Your code

# %% [markdown]
# **E2.** Test using store_with_words.

# %%
# Your test

# %% [markdown]
# **E3.** Test using tmp_path for save/load.

# %%
# Your test

# %% [markdown]
# **E4.** Use capsys to verify a CLI command prints expected text.

# %%
# Your test

# %% [markdown]
# **E5.** Parametrize using a fixture.

# %%
# Your test (combine parametrize and fixture)

# %% [markdown]
# **E6.** Module-scoped expensive fixture (mock real API).

# %%
# Your code

# %% [markdown]
# **E7.** Cleanup demo: a fixture using `yield`.

# %%
# Your code

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
