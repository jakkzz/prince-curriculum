# %% [markdown]
# # Day 17 Quiz — TDD
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/17-tdd-quiz.ipynb)
#
# > 🎯 **What this tests.** Test-Driven Development cycle (red-green-refactor), test-first thinking, why it works.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** What's TDD?

# %% [markdown]
# **A2.** The TDD cycle has how many steps?

# %% [markdown]
# **A3.** Why see the test fail first?

# %% [markdown]
# **A4.** What's the 'green' step?

# %% [markdown]
# **A5.** Why is TDD claimed to lead to cleaner APIs?

# %% [markdown]
# **A6.** When should you skip TDD?

# %% [markdown]
# **A7.** What's wrong with writing all tests AFTER the code?

# %% [markdown]
# **A8.** What does 'refactor' mean in the TDD cycle?

# %% [markdown]
# **A9.** TDD: when do you commit?

# %% [markdown]
# **A10.** What's the strongest argument FOR TDD?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
# A: write test
def test_search():
    assert WordStore().search('x') == []
# B: code doesn't exist yet
WordStore().search('x')

# %% [markdown]
# **B2.**

# %%
# search added: returns []
class WordStore:
    def search(self, p): return []
# Run test:
assert WordStore().search('x') == []

# %% [markdown]
# **B3.**

# %%
# next test added:
store = WordStore()
store.add(Word('thorough'))
assert store.search('th') == ['thorough'] or False

# %% [markdown]
# **B4.**

# %%
def search(self, p):
    return [w for w in self.words.values() if p in w.word]

# %% [markdown]
# **B5.**

# %%
def f(): assert False
f()

# %% [markdown]
# **B6.**

# %%
def search(self, p):
    p = p.lower()
    return [w for w in self.words.values() if p in w.word.lower()]
# now test:
store = WordStore(); store.add(Word('Thorough'))
result = store.search('THOROUGH')

# %% [markdown]
# **B7.**

# %%
# RED-GREEN-REFACTOR:
# write failing test
# write min code
# clean up
# next test still passes?

# %% [markdown]
# **B8.**

# %%
# Two tests:
# - search returns list
# - search empty list when no match
store = WordStore()
result = store.search('nothing')
assert isinstance(result, list) and result == []

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Write the first failing test for `Word.shout()` (returns 'WORD!').

# %%
def test_word_shout():
    ???

# %% [markdown]
# **C2.** Write the minimal impl to make C1 pass.

# %%
@dataclass(frozen=True)
class Word:
    word: str
    ipa: str = ''
    ???

# %% [markdown]
# **C3.** Write the test for empty word.

# %%
def test_word_shout_empty():
    ???

# %% [markdown]
# **C4.** Write a failing test for `WordStore.count()`.

# %%
def test_word_store_count():
    ???

# %% [markdown]
# **C5.** Min impl for `count()`.

# %%
@dataclass
class WordStore:
    words: dict[str, Word] = field(default_factory=dict)
    ???

# %% [markdown]
# **C6.** Write 3 parametrize cases for a `multiply_by_two` function.

# %%
import pytest
???
def test_multiply_by_two(input, expected):
    assert input * 2 == expected

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
# You write a test:
def test_search():
    assert WordStore().search('x') == [] or True  # bug?

# %% [markdown]
# **D2.**

# %%
# Test that 'thorough' is found
store = WordStore()
store.add(Word('thorough'))
assert store.search('th') == ['thorough']

# %% [markdown]
# **D3.**

# %%
# Forgot to call the function
assert WordStore.search == ['thorough']

# %% [markdown]
# **D4.**

# %%
# Test name not prefixed
def search_test():  # not test_*
    assert False

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** TDD red: failing test for `WordStore.starting_with(letter)`.

# %%
# Your code

# %% [markdown]
# **E2.** TDD green: minimum impl.

# %%
# Your code

# %% [markdown]
# **E3.** TDD red: edge case test (capital letter).

# %%
# Your test

# %% [markdown]
# **E4.** Confirm the impl already handles capital. If not, fix.

# %%
# Verify

# %% [markdown]
# **E5.** TDD red: test that `starting_with('')` returns nothing.

# %%
# Your test

# %% [markdown]
# **E6.** Update impl to return [] on empty pattern (cleaner UX).

# %%
# Your code

# %% [markdown]
# **E7.** Add the CLI command to wire it up (TDD on cli is overkill, but show how).

# %%
# Your code

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
