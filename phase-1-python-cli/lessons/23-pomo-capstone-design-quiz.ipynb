# %% [markdown]
# # Day 23 Quiz — Pomo Capstone Design
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/23-pomo-capstone-design-quiz.ipynb)
#
# > 🎯 **What this tests.** Design-first thinking, SQLite + Python's sqlite3, schema design, applying Phase 1 patterns to a new domain.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** Why write DESIGN.md before code?

# %% [markdown]
# **A2.** Why SQLite for pomo?

# %% [markdown]
# **A3.** Why a `tag` column nullable?

# %% [markdown]
# **A4.** Why `ended_at` nullable?

# %% [markdown]
# **A5.** What's a transaction in SQLite?

# %% [markdown]
# **A6.** Why store datetime as ISO string in SQLite?

# %% [markdown]
# **A7.** Why parameter substitution `?` instead of f-strings in SQL?

# %% [markdown]
# **A8.** Why an `id INTEGER PRIMARY KEY AUTOINCREMENT`?

# %% [markdown]
# **A9.** What's the right place for `~/.pomo/pomo.db`?

# %% [markdown]
# **A10.** Should you let Storage manage the connection lifecycle?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
import sqlite3
conn = sqlite3.connect(':memory:')
conn.execute('CREATE TABLE t (x INTEGER)')
conn.execute('INSERT INTO t VALUES (?)', (5,))
conn.commit()
print(conn.execute('SELECT * FROM t').fetchone())

# %% [markdown]
# **B2.**

# %%
conn.execute('SELECT * FROM t WHERE x = ?', (99,)).fetchone()

# %% [markdown]
# **B3.**

# %%
for row in conn.execute('SELECT * FROM t'):
    print(row)

# %% [markdown]
# **B4.**

# %%
cur = conn.execute('INSERT INTO t VALUES (?)', (42,))
print(cur.lastrowid)

# %% [markdown]
# **B5.**

# %%
# After commit:
conn.execute('UPDATE t SET x = 0 WHERE id = 1')
conn.commit()
# Re-fetch shows the update

# %% [markdown]
# **B6.**

# %%
from datetime import datetime
print(datetime.now().isoformat())

# %% [markdown]
# **B7.**

# %%
from datetime import datetime
dt = datetime.fromisoformat('2026-05-15T14:23:11')
print(dt.year, dt.hour)

# %% [markdown]
# **B8.**

# %%
conn.execute('INSERT INTO t (x) VALUES (?)', ('hello',))

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Create the sessions table.

# %%
conn.execute(???)

# %% [markdown]
# **C2.** Insert a session safely.

# %%
conn.execute(???, (started.isoformat(), 25, 'phase-1'))

# %% [markdown]
# **C3.** Find the active session (no ended_at).

# %%
active = conn.execute(???).fetchone()

# %% [markdown]
# **C4.** Update session to mark as stopped.

# %%
conn.execute(???, (ended_at.isoformat(), session_id))

# %% [markdown]
# **C5.** Aggregate total minutes by tag.

# %%
rows = conn.execute(???).fetchall()

# %% [markdown]
# **C6.** Filter sessions by date range.

# %%
since = '2026-05-01'
rows = conn.execute(???).fetchall()

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
conn.execute(f"INSERT INTO sessions (tag) VALUES ('{tag}')")

# %% [markdown]
# **D2.**

# %%
conn.execute('INSERT INTO sessions (tag) VALUES (?)', ('phase-1'))

# %% [markdown]
# **D3.**

# %%
conn = sqlite3.connect(':memory:')
conn.execute('CREATE TABLE t (x)')
conn.execute('INSERT INTO t VALUES (1)')
# Don't commit. Close. Reconnect.
conn.close()
conn = sqlite3.connect(':memory:')
print(conn.execute('SELECT * FROM t').fetchall())

# %% [markdown]
# **D4.**

# %%
for row in conn.execute('SELECT * FROM sessions'):
    print(row)
# In a separate query a moment later — locked?

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Storage class skeleton with init and schema.

# %%
import sqlite3
from pathlib import Path
class Storage:
    ???

# %% [markdown]
# **E2.** `start(duration_min, tag)` — refuses if another session is active.

# %%
# Your code

# %% [markdown]
# **E3.** `stop()` — finalizes the active session.

# %%
# Your code

# %% [markdown]
# **E4.** `list(since: str | None)` — return all sessions matching range.

# %%
# Your code

# %% [markdown]
# **E5.** `report()` — total minutes per tag, sorted desc.

# %%
# Your code

# %% [markdown]
# **E6.** pytest test for `start` + `stop` round trip.

# %%
# Your test

# %% [markdown]
# **E7.** pytest test that `start` while another active raises.

# %%
# Your test

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
