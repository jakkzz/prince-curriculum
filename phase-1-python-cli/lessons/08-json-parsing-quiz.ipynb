# %% [markdown]
# # Day 8 Quiz — JSON Parsing & Defensive Code
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/08-json-parsing-quiz.ipynb)
#
# > 🎯 **What this tests.** JSON-Python conversion, safe traversal with `.get()`, walrus, file I/O, robust API parsing.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** Python equivalent of JSON `null`?

# %% [markdown]
# **A2.** What's JSON `true` parsed as in Python?

# %% [markdown]
# **A3.** What does `d.get('key')` return if 'key' is missing?

# %% [markdown]
# **A4.** What's the walrus operator `:=`?

# %% [markdown]
# **A5.** Which is safer for accessing the first item of an unknown list?

# %% [markdown]
# **A6.** What does `json.dumps({'x': 1}, indent=2)` produce?

# %% [markdown]
# **A7.** What exception does `json.loads('not json')` raise?

# %% [markdown]
# **A8.** Why pass `ensure_ascii=False` when writing Thai content?

# %% [markdown]
# **A9.** What's safer to access deeply nested optional data?

# %% [markdown]
# **A10.** Why might you use Pydantic instead of manual `.get()` chains?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
import json
print(json.loads('null'))
print(json.loads('true'))
print(json.loads('[]'))

# %% [markdown]
# **B2.**

# %%
d = {'a': 1, 'b': 2}
print(d.get('a'), d.get('c'), d.get('c', 99))

# %% [markdown]
# **B3.**

# %%
data = {'phonetics': []}
print(data['phonetics'][0] if data['phonetics'] else 'empty')

# %% [markdown]
# **B4.**

# %%
d = {}
x = d.get('a', {}).get('b', 'missing')
print(x)

# %% [markdown]
# **B5.**

# %%
import json
print(json.dumps({'name': 'ปริ้นซ์'}, ensure_ascii=False))

# %% [markdown]
# **B6.**

# %%
import json
print(json.dumps({'name': 'ปริ้นซ์'}))

# %% [markdown]
# **B7.**

# %%
data = {'phonetics': [{'text': '/x/', 'audio': ''}, {'text': '/y/', 'audio': 'http://...'}]}
for p in data['phonetics']:
    if p['audio']:
        print(p['audio'])

# %% [markdown]
# **B8.**

# %%
if (name := 'Prince') and len(name) > 3:
    print(name)

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Safely get the nested `entry['meanings'][0]['definitions'][0]['definition']` — return 'no def' if missing.

# %%
entry = {'meanings': []}
# Your code

# %% [markdown]
# **C2.** Filter a list of phonetics to only those with non-empty audio.

# %%
phonetics = [{'text': '/x/', 'audio': ''}, {'text': '/y/', 'audio': 'http://...'}]
# Your code

# %% [markdown]
# **C3.** Save the dict to /tmp/data.json with pretty-print and unicode preserved.

# %%
import json
from pathlib import Path
data = {'name': 'ปริ้นซ์'}
???

# %% [markdown]
# **C4.** Load JSON file, return empty dict if it doesn't exist or is corrupt.

# %%
from pathlib import Path
import json
path = Path('/tmp/data.json')
???

# %% [markdown]
# **C5.** Walrus operator: in one if-statement, assign + test.

# %%
user = {'email': 'a@b.c'}
# Use walrus to assign email and check if it has '@'
???

# %% [markdown]
# **C6.** Normalize an API entry to {word, ipa, definition} — defaults to empty strings.

# %%
api_response = {'word': 'thorough', 'phonetics': [{'text': '/x/'}]}
# Your code

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
import json
data = json.loads('{}')
print(data['phonetics'][0])

# %% [markdown]
# **D2.**

# %%
import json
import pathlib
path = pathlib.Path('/tmp/data.json')
data = json.loads(path.read_text())

# %% [markdown]
# **D3.**

# %%
import json
print(json.dumps({1: 'one', 2: 'two'}))

# %% [markdown]
# **D4.**

# %%
data = {'phonetics': [{'text': '/x/'}, {'text': '/y/'}]}
ipa = data['phonetics'][2]['text']

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** `safe_get_ipa(entry)` — returns IPA from first phonetic with text, else from top-level `phonetic` field, else empty string.

# %%
# Your code

# %% [markdown]
# **E2.** `safe_get_audio(entry)` — returns first non-empty audio URL.

# %%
# Your code

# %% [markdown]
# **E3.** `safe_get_definition(entry, max_chars=200)` — returns first definition trimmed to max_chars.

# %%
# Your code

# %% [markdown]
# **E4.** `normalize(entry)` — combine the three into a single dict with keys word, ipa, audio, definition.

# %%
# Your code, using functions from E1-E3

# %% [markdown]
# **E5.** `load_cache(path)` — load JSON file, return empty dict on missing or corrupt.

# %%
from pathlib import Path
import json
# Your code

# %% [markdown]
# **E6.** `save_cache(path, data)` — pretty-print, unicode preserved.

# %%
from pathlib import Path
import json
# Your code

# %% [markdown]
# **E7.** Add a defensive test in `__main__` that calls normalize() on three weird inputs.

# %%
# Your code

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
