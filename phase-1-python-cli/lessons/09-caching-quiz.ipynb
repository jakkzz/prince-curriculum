# %% [markdown]
# # Day 9 Quiz — Caching
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/09-caching-quiz.ipynb)
#
# > 🎯 **What this tests.** When to cache, in-memory vs file, TTL, `lru_cache`, cache invalidation.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** Why cache?

# %% [markdown]
# **A2.** What's a cache hit?

# %% [markdown]
# **A3.** When does TTL matter?

# %% [markdown]
# **A4.** What does `@lru_cache(maxsize=100)` do?

# %% [markdown]
# **A5.** Why won't `lru_cache` work with a function that takes a `list`?

# %% [markdown]
# **A6.** When does a file cache outperform an in-memory cache?

# %% [markdown]
# **A7.** When should you NOT use lru_cache on a network function?

# %% [markdown]
# **A8.** What's cache invalidation?

# %% [markdown]
# **A9.** What's a good cache key for `fetch_word(word)`?

# %% [markdown]
# **A10.** What's a downside of a JSON file cache?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
from functools import lru_cache

@lru_cache(maxsize=2)
def f(x):
    print(f'computing {x}')
    return x * 2

print(f(1)); print(f(1)); print(f(2))

# %% [markdown]
# **B2.**

# %%
from functools import lru_cache

@lru_cache(maxsize=2)
def f(x):
    print(f'computing {x}')
    return x

f(1); f(2); f(3); f(1)

# %% [markdown]
# **B3.**

# %%
from functools import lru_cache
import time

@lru_cache
def slow(x):
    time.sleep(0.5)
    return x

start = time.time()
for _ in range(3): slow(1)
print(f'Took {time.time()-start:.2f}s')

# %% [markdown]
# **B4.**

# %%
cache = {}
cache['x'] = 1
print('x' in cache, 'y' in cache)

# %% [markdown]
# **B5.**

# %%
cache = {'thorough': '/ˈθʌrə/'}
word = 'Thorough'
print(cache.get(word.lower()))

# %% [markdown]
# **B6.**

# %%
from functools import lru_cache

@lru_cache
def f(x):
    return x * 2

f(5)
print(f.cache_info())

# %% [markdown]
# **B7.**

# %%
from functools import lru_cache
@lru_cache
def f(x): return x
f([1, 2, 3])

# %% [markdown]
# **B8.**

# %%
from functools import lru_cache
@lru_cache
def f(x): return x
f(5); f(5); f(5)
f.cache_clear()
print(f.cache_info())

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Apply lru_cache to this slow function.

# %%
import time
???
def slow_lookup(word):
    time.sleep(1)
    return word.upper()

# %% [markdown]
# **C2.** Load a JSON cache from disk; return empty dict if missing.

# %%
from pathlib import Path
import json
path = Path.home() / '.cache.json'
???

# %% [markdown]
# **C3.** Save cache to disk pretty-printed.

# %%
from pathlib import Path
import json
cache = {'thorough': {'ipa': '/x/'}}
path = Path.home() / '.cache.json'
???

# %% [markdown]
# **C4.** Check if entry is fresh (less than 1 hour old). `entry` has `stored_at` (unix time).

# %%
import time
entry = {'stored_at': time.time() - 100, 'data': {}}
is_fresh = ???
print(is_fresh)

# %% [markdown]
# **C5.** Cache decorator that uses your dict-and-json approach.

# %%
import json
from pathlib import Path

CACHE = Path('/tmp/cache.json')

def cached(fn):
    # Your code: wrap fn so it checks/saves from CACHE
    ...

# %% [markdown]
# **C6.** Clear all entries from a cache file.

# %%
from pathlib import Path
cache_path = Path('/tmp/cache.json')
???

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
from functools import lru_cache
@lru_cache
def fetch(word, options):
    return options.get('format', 'text')

fetch('thorough', {'format': 'json'})

# %% [markdown]
# **D2.**

# %%
cache = {}
def get(word):
    if word in cache:
        return cache[word]
    cache[word] = fetch(word)  # but cache is local to module — does it persist between runs?

# %% [markdown]
# **D3.**

# %%
import time
entry = {'data': {}, 'stored_at': '2026-01-01'}  # string, not timestamp!
if time.time() - entry['stored_at'] < 3600: ...

# %% [markdown]
# **D4.**

# %%
import json
from pathlib import Path
cache = json.loads(Path('/tmp/cache.json').read_text())
# Two processes both run this simultaneously, both modify, both save.

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Write `load_cache(path) -> dict` — returns empty dict if missing.

# %%
from pathlib import Path
import json
# Your code

# %% [markdown]
# **E2.** Write `save_cache(path, data) -> None` — atomic-ish: write to .tmp then rename.

# %%
from pathlib import Path
import json
# Your code

# %% [markdown]
# **E3.** Write `get_or_fetch(word, fetch_fn) -> dict | None` — checks cache, falls back to fetch_fn.

# %%
from pathlib import Path
CACHE_PATH = Path.home() / '.english-helper' / 'api_cache.json'
# Your code

# %% [markdown]
# **E4.** Add cache stats: `cache_stats() -> dict` returning {entries, size_bytes}.

# %%
from pathlib import Path
# Your code

# %% [markdown]
# **E5.** Write `clear_cache() -> int` — removes the file, returns number of entries removed.

# %%
from pathlib import Path
# Your code

# %% [markdown]
# **E6.** Add TTL: skip cache hits older than 30 days. Store `stored_at` with each entry.

# %%
import time
# Your code — augmented get_or_fetch

# %% [markdown]
# **E7.** Wire `english-helper add <word>` to use `get_or_fetch`. Show user 'cached' or 'fetched' in output.

# %%
# Sketch the CLI command handler

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
