# %% [markdown]
# # Day 5 Quiz — Lists, Dicts, Sets
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/05-lists-dicts-sets-quiz.ipynb)
#
# > 🎯 **What this tests.** Collection methods, picking the right structure, comprehensions in all forms, JSON read/write. This is the Phase 1 Week 1 capstone quiz — covers a bit of everything you've learned.
#
# **Time:** 45–60 min. No AI.
# **Passing:** 28/35.
#
# ## Sections
#
# - **A** — MCQ (10)
# - **B** — Predict (8)
# - **C** — Fill in (6)
# - **D** — Debug (4)
# - **E** — Write code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** Which is O(1) for membership testing?
#
# A) `list`
# B) `tuple`
# C) `set`
# D) `str`

# %% [markdown]
# **A2.** What does `list(set([1,2,2,3,3,3]))` produce?
#
# A) `[1,2,3]` guaranteed in order
# B) `[1,2,3]` but in any order
# C) `[1,2,2,3,3,3]`
# D) Error

# %% [markdown]
# **A3.** Difference between `sort()` and `sorted()`?
#
# A) None — they're aliases
# B) `sort()` mutates the list and returns None; `sorted()` returns a new list
# C) `sort()` returns a list; `sorted()` mutates
# D) `sorted()` is faster

# %% [markdown]
# **A4.** Best way to count occurrences in a list?
#
# A) Manual `for` loop with a dict
# B) `xs.count(item)` for each item
# C) `from collections import Counter; Counter(xs)`
# D) All of the above

# %% [markdown]
# **A5.** `d.get(key, default)` does what?
#
# A) Same as `d[key]`
# B) Returns the value or the default if key missing — never raises
# C) Adds the default to the dict if missing
# D) Raises KeyError

# %% [markdown]
# **A6.** What's the type of `{}`?
#
# A) `set`
# B) `dict`
# C) `frozenset`
# D) Empty list

# %% [markdown]
# **A7.** Which dedupes while preserving order?
#
# A) `list(set(xs))`
# B) `list(dict.fromkeys(xs))`
# C) `xs.unique()`
# D) `set(xs)`

# %% [markdown]
# **A8.** What's `a & b` for sets?
#
# A) Concatenation
# B) Intersection
# C) Union
# D) Difference

# %% [markdown]
# **A9.** What does `json.loads('null')` return?
#
# A) `"null"`
# B) `None`
# C) Empty dict
# D) Error

# %% [markdown]
# **A10.** Why pass `ensure_ascii=False` to `json.dumps`?
#
# A) To enable ASCII
# B) Keeps non-ASCII chars (like Thai) readable instead of escaped to \u...
# C) Smaller file
# D) Faster

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
xs = [3, 1, 4]
ys = sorted(xs, reverse=True)
print(xs)
print(ys)

# %% [markdown]
# **B2.**

# %%
d = {'a': 1, 'b': 2}
for k, v in d.items():
    print(k, v)

# %% [markdown]
# **B3.**

# %%
s = {1, 2, 3}
s.add(2)
print(len(s))

# %% [markdown]
# **B4.**

# %%
a = {1, 2, 3}
b = {3, 4, 5}
print(a | b)
print(a & b)

# %% [markdown]
# **B5.**

# %%
words = ['cat', 'dog', 'fish']
print({w: len(w) for w in words})

# %% [markdown]
# **B6.**

# %%
xs = [1, 2, 3]
xs.append([4, 5])
print(xs)
print(len(xs))

# %% [markdown]
# **B7.**

# %%
data = '{"name": "prince", "score": 95}'
import json
obj = json.loads(data)
print(obj['score'] + 5)

# %% [markdown]
# **B8.**

# %%
import json
d = {'th': 'ละเอียด'}
print(json.dumps(d))
print(json.dumps(d, ensure_ascii=False))

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Given a list of integers, return a new list of just the unique values (order doesn't matter).

# %%
xs = [1, 2, 2, 3, 3, 3, 4]
unique = ???
print(unique)

# %% [markdown]
# **C2.** Given a list of strings, return a dict mapping each string to its length.

# %%
words = ['cat', 'fish', 'whale']
lengths = ???
print(lengths)

# %% [markdown]
# **C3.** Use a set to check whether two lists share ANY element.

# %%
a = [1, 2, 3]
b = [4, 5, 1]
shares = ???
print(shares)

# %% [markdown]
# **C4.** Save a dict to a JSON file with Thai characters preserved and 2-space indentation.

# %%
import json
from pathlib import Path
data = {'word': 'thorough', 'thai': 'ละเอียด'}
# Your code: write to /tmp/out.json

# %% [markdown]
# **C5.** Read a JSON file back into a Python dict.

# %%
import json
from pathlib import Path
# Your code: load /tmp/out.json into `loaded`

# %% [markdown]
# **C6.** Given a dict, get the value for `'age'` — or `0` if missing — without raising.

# %%
user = {'name': 'Prince'}
age = ???
print(age)

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
xs = [3, 1, 4]
xs = xs.sort()
print(xs)

# %% [markdown]
# **D2.**

# %%
d = {'a': 1}
print(d['b'])

# %% [markdown]
# **D3.**

# %%
fruits = {'apple', 'banana'}
for i in range(len(fruits)):
    print(fruits[i])

# %% [markdown]
# **D4.**

# %%
import json
d = {1: 'a', 2: 'b'}
print(json.dumps(d))

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1. Convert.**
#
# Given a `list[dict]` where each dict has `word`, `ipa`, `thai` — convert to a single `dict` keyed by `word` (so values are `{'ipa': ..., 'thai': ...}`). Type hints required.

# %%
WordEntry = dict[str, str]
words: list[WordEntry] = [
    {'word': 'thorough', 'ipa': '/ˈθʌrə/', 'thai': 'ละเอียด'},
    {'word': 'nuance', 'ipa': '/ˈnuːɑːns/', 'thai': 'ความละเอียดอ่อน'},
]
# Your code: build `by_word: dict[str, dict[str, str]]`

# %% [markdown]
# **E2. Stats.**
#
# Given the `by_word` dict from E1, compute: total entries, set of unique first letters, longest word.

# %%
by_word = {
    'thorough': {'ipa': '/ˈθʌrə/', 'thai': 'ละเอียด'},
    'nuance':   {'ipa': '/ˈnuːɑːns/', 'thai': 'ความละเอียดอ่อน'},
    'resilient': {'ipa': '/rɪˈzɪliənt/', 'thai': 'ยืดหยุ่น'},
}
# Your code: print total, first_letters set, longest word

# %% [markdown]
# **E3. Persist.**
#
# Write `save_words(store, path)` — saves a `dict[str, dict[str, str]]` to a JSON file. Use ensure_ascii=False and indent=2.

# %%
from pathlib import Path
import json
# Your code

# %% [markdown]
# **E4. Load.**
#
# Write `load_words(path)` — returns the loaded dict, or an empty dict if the file doesn't exist.

# %%
from pathlib import Path
import json
# Your code

# %% [markdown]
# **E5. Search.**
#
# Write `search(store, pattern)` — returns a list of words whose name CONTAINS `pattern` (case-insensitive). E.g., `search(store, 'th')` → `['thorough']` if 'thorough' is the only match.

# %%
# Your code

# %% [markdown]
# **E6. Sort by length.**
#
# Given your store, return the words sorted by length (shortest first), then alphabetically for ties.

# %%
# Your code

# %% [markdown]
# **E7. Merge.**
#
# Merge two word stores. If a word appears in both, keep the entry from `store_b` (newer wins).

# %%
store_a = {'thorough': {'ipa': '/ˈθʌrə/', 'thai': 'ละเอียด'}}
store_b = {'thorough': {'ipa': '/ˈθʌroʊ/', 'thai': 'ละเอียด'}, 'nuance': {'ipa': '/ˈnuːɑːns/', 'thai': 'ความละเอียดอ่อน'}}
# Your code: produce merged store

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# | Score | Meaning |
# |-------|---------|
# | 33–35 | Solid finish to Week 1. |
# | 28–32 | Pass. |
# | 21–27 | Re-read [05-lists-dicts-sets.ipynb](05-lists-dicts-sets.ipynb). Retake. |
# | < 21  | Re-do the lesson and the JSON section especially. |
#
# ## End of Phase 1 Week 1
#
# You've shipped 5 mini-projects and taken 5 quizzes. **You have a working English-learning tool.** Use it daily for the next 4 weeks while you work through Phase 1 Weeks 2–5.
#
# Next: Phase 1 Week 2 — testing, then `requests`, then connecting your tool to the real Free Dictionary API. Your english-helper goes online.
