# %% [markdown]
# # Day 15 Quiz — Spaced Repetition
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/15-spaced-repetition-quiz.ipynb)
#
# > 🎯 **What this tests.** SM-2 algorithm, datetime/timedelta, scheduler design, persisting per-word state.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** What's spaced repetition?

# %% [markdown]
# **A2.** What's `timedelta(days=1)`?

# %% [markdown]
# **A3.** What's `datetime.now() + timedelta(days=2)`?

# %% [markdown]
# **A4.** Why is `ease=2.5` a common default?

# %% [markdown]
# **A5.** When user gets a word wrong, what happens to `ease`?

# %% [markdown]
# **A6.** Where should ReviewState live?

# %% [markdown]
# **A7.** What does 'due today' mean?

# %% [markdown]
# **A8.** Why cap interval at 180 days?

# %% [markdown]
# **A9.** Why store `datetime` not `int` for next_review?

# %% [markdown]
# **A10.** How do you serialize datetime to JSON?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
from datetime import datetime, timedelta
now = datetime(2026, 5, 15)
print(now + timedelta(days=3))

# %% [markdown]
# **B2.**

# %%
from datetime import datetime, timedelta
print(timedelta(days=2.5).total_seconds())

# %% [markdown]
# **B3.**

# %%
from datetime import datetime, timedelta
import time
old = datetime.now()
time.sleep(0.1)
print((datetime.now() - old).total_seconds() > 0.05)

# %% [markdown]
# **B4.**

# %%
from datetime import datetime
s = datetime(2026, 5, 15).isoformat()
print(s)

# %% [markdown]
# **B5.**

# %%
from datetime import datetime
d = datetime.fromisoformat('2026-05-15T10:30:00')
print(d.year, d.hour)

# %% [markdown]
# **B6.**

# %%
from dataclasses import dataclass
@dataclass
class S:
    ease: float = 2.5
print(S().ease)
print(S(ease=1.5).ease)

# %% [markdown]
# **B7.**

# %%
interval = 1.0
ease = 2.5
for _ in range(3):
    interval = min(interval * ease, 180)
print(interval)

# %% [markdown]
# **B8.**

# %%
ease = 2.5
for _ in range(10):
    ease = max(ease - 0.2, 1.3)
print(ease)

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** ReviewState dataclass with the 6 fields from the lesson.

# %%
from datetime import datetime
from dataclasses import dataclass
???

# %% [markdown]
# **C2.** Method record_review handling correct + incorrect.

# %%
from datetime import datetime, timedelta
class Scheduler:
    ???

# %% [markdown]
# **C3.** Filter due-today.

# %%
def due_today(states):
    now = ???
    return [s for s in states if ???]

# %% [markdown]
# **C4.** Serialize ReviewState to dict (handle None).

# %%
def to_dict(state):
    ???

# %% [markdown]
# **C5.** Deserialize dict → ReviewState (handle None).

# %%
def from_dict(d):
    ???

# %% [markdown]
# **C6.** Update WordStore to track review states.

# %%
@dataclass
class WordStore:
    words: dict[str, Word] = field(default_factory=dict)
    ???

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
from datetime import datetime
state = {'next_review': None}
if state['next_review'] <= datetime.now():
    print('due')

# %% [markdown]
# **D2.**

# %%
import json
from datetime import datetime
json.dumps({'now': datetime.now()})

# %% [markdown]
# **D3.**

# %%
interval = 1.0; ease = 2.5
for _ in range(100):
    interval = interval * ease
print(interval)

# %% [markdown]
# **D4.**

# %%
ease = 2.5
for _ in range(20):
    ease -= 0.2  # no floor

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Full Scheduler class with record_review and due_today.

# %%
from datetime import datetime, timedelta
from dataclasses import dataclass
# Your code

# %% [markdown]
# **E2.** Save & load WordStore including reviews.

# %%
# Your code

# %% [markdown]
# **E3.** A `cmd_due` that shows count of due words.

# %%
# Your code

# %% [markdown]
# **E4.** A `cmd_review` that runs through due words.

# %%
# Your code

# %% [markdown]
# **E5.** Test the algorithm: simulate 5 successful reviews of one word, print the interval after each.

# %%
# Your code

# %% [markdown]
# **E6.** Test the wrong-answer case: 3 right then 1 wrong then 1 right — show what happens to interval and ease.

# %%
# Your code

# %% [markdown]
# **E7.** Show how `Quizzer` from Day 14 could use the scheduler for next_word selection — a new QuizMode subclass `SpacedRepetitionQuiz`.

# %%
# Your code

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
