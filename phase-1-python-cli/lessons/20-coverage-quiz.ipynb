# %% [markdown]
# # Day 20 Quiz — Coverage & CI
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/20-coverage-quiz.ipynb)
#
# > 🎯 **What this tests.** coverage tool, reading reports, what to chase, CI configuration, GitHub Actions.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** What does coverage measure?

# %% [markdown]
# **A2.** Does 100% coverage mean correct?

# %% [markdown]
# **A3.** Realistic coverage target?

# %% [markdown]
# **A4.** Most valuable uncovered lines to test?

# %% [markdown]
# **A5.** What's `branch coverage`?

# %% [markdown]
# **A6.** What does `fail_under = 80` do in pyproject.toml?

# %% [markdown]
# **A7.** What runs on GitHub Actions?

# %% [markdown]
# **A8.** Why run lint + tests in CI?

# %% [markdown]
# **A9.** Should you commit a `coverage` HTML report?

# %% [markdown]
# **A10.** What's a coverage badge?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
# coverage output: word.py 20/20 100%
print('total cover ok?')

# %% [markdown]
# **B2.**

# %%
# storage.py: Missing 23-25
# That's a 3-line block. What might it be?

# %% [markdown]
# **B3.**

# %%
# A test exercises the True branch of:
# if x > 0: do_a()
# else: do_b()
# Coverage reports 100% line coverage. Branch coverage?

# %% [markdown]
# **B4.**

# %%
# Three test files; coverage runs; HTML report shows:
# word.py 100% (40/40)
# storage.py 85% (45/53)
# api.py 60% (24/40)
# What's total?

# %% [markdown]
# **B5.**

# %%
# pyproject.toml: fail_under = 90, current coverage is 84%
uv run pytest --cov

# %% [markdown]
# **B6.**

# %%
# .coveragerc:
# exclude_lines = ['raise NotImplementedError']
# Line in code: raise NotImplementedError
# Coverage report?

# %% [markdown]
# **B7.**

# %%
# Code:
# if VERBOSE: print('debug')
# Test runs without VERBOSE. Branch coverage?

# %% [markdown]
# **B8.**

# %%
# A function with 4 returns based on conditions. Coverage shows 100% line.
# Is it sufficient?

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Install coverage as dev dependency.

# %%
# pyproject.toml or uv add
???

# %% [markdown]
# **C2.** Run coverage with terminal report.

# %%
???

# %% [markdown]
# **C3.** Add coverage config to pyproject.toml.

# %%
[tool.coverage.run]
???

# %% [markdown]
# **C4.** Add fail_under threshold.

# %%
[tool.coverage.report]
???

# %% [markdown]
# **C5.** GitHub Actions workflow.

# %%
# .github/workflows/test.yml
name: tests
???

# %% [markdown]
# **C6.** README coverage badge.

# %%
# README.md
???

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
# coverage: 79%, fail_under = 80
CI fails. What to do?

# %% [markdown]
# **D2.**

# %%
# Mypy passes; coverage shows storage.py 50%. Tests run green.
# What does this mean?

# %% [markdown]
# **D3.**

# %%
# Tests pass locally; fail in CI.

# %% [markdown]
# **D4.**

# %%
# A function:
def parse_age(s):
    try:
        return int(s)
    except ValueError:
        return 0
# Test only calls parse_age('42'). Coverage shows 100%?

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Add a test that increases coverage on `storage.py` by exercising the no-path case.

# %%
# Your test

# %% [markdown]
# **E2.** Write tests to cover both branches of `if word in store.review:`.

# %%
# Your tests

# %% [markdown]
# **E3.** Configure pyproject.toml for coverage with 85% fail_under on critical modules.

# %%
# Your config

# %% [markdown]
# **E4.** GitHub Actions workflow that runs lint, mypy, tests, fails CI on issues.

# %%
# .github/workflows/test.yml

# %% [markdown]
# **E5.** Add a README badge.

# %%
# README.md

# %% [markdown]
# **E6.** Write a test that catches a branch coverage gap.

# %%
# Example function and test

# %% [markdown]
# **E7.** Identify why a coverage gap might exist on Line 23-25 of `storage.py` (defensive code) — and decide whether to test it or exclude it.

# %%
# Walkthrough

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
