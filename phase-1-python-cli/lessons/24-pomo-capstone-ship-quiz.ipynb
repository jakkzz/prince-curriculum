# %% [markdown]
# # Day 24 Quiz — Pomo Ship
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/24-pomo-capstone-ship-quiz.ipynb)
#
# > 🎯 **What this tests.** argparse-driven CLI, SQLite integration tests, monkeypatch for paths, subprocess testing, end-to-end install.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** Why have one entry point `main()` instead of multiple scripts?

# %% [markdown]
# **A2.** Why does `cmd_start(args)` take a Namespace instead of individual args?

# %% [markdown]
# **A3.** What does `subprocess.run([...], capture_output=True)` give you?

# %% [markdown]
# **A4.** Why use a sentinel `SystemExit(1)` instead of `sys.exit(1)`?

# %% [markdown]
# **A5.** Why monkeypatch DB_PATH in tests?

# %% [markdown]
# **A6.** For pomo, why is `[dependencies]` empty?

# %% [markdown]
# **A7.** Why ship a CI badge?

# %% [markdown]
# **A8.** What's wrong with `print('Error: ...')` then `return 1`?

# %% [markdown]
# **A9.** What error should `pomo stop` raise when no session is running?

# %% [markdown]
# **A10.** When use sqlite3.Row?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
# argparse: pomo start --duration 30 --tag focus
# In code: args = parser.parse_args()
# What's args.duration, args.tag?

# %% [markdown]
# **B2.**

# %%
# pomo --help

# %% [markdown]
# **B3.**

# %%
# pomo (no subcommand)
# parser has required=True on subparsers

# %% [markdown]
# **B4.**

# %%
import subprocess
result = subprocess.run(['pomo', '--help'], capture_output=True, text=True)
print(result.returncode)

# %% [markdown]
# **B5.**

# %%
# Inside cmd_start, if Storage.start raises:
try: cmd_start(args)
except ValueError as e: print(e)

# %% [markdown]
# **B6.**

# %%
# pomo start --duration -1

# %% [markdown]
# **B7.**

# %%
# pomo start --duration abc

# %% [markdown]
# **B8.**

# %%
from argparse import Namespace
args = Namespace(duration=25, tag='x')
print(args.duration)
args.something = 99
print(args.something)

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Build the argparse parser with start, stop, list.

# %%
import argparse
def build_parser():
    ???

# %% [markdown]
# **C2.** main() that dispatches with friendly error handling.

# %%
def main():
    parser = build_parser()
    args = parser.parse_args()
    ???

# %% [markdown]
# **C3.** Test that monkeypatches DB_PATH.

# %%
def test_start(tmp_path, monkeypatch):
    import pomo.cli
    ???

# %% [markdown]
# **C4.** subprocess test of `pomo --help`.

# %%
import subprocess
def test_help():
    ???

# %% [markdown]
# **C5.** Capsys test of cmd_list output.

# %%
def test_list_empty(tmp_path, monkeypatch, capsys):
    import pomo.cli
    monkeypatch.setattr(pomo.cli, 'DB_PATH', tmp_path / 'pomo.db')
    args = Namespace(since=None)
    ???

# %% [markdown]
# **C6.** pyproject.toml entry point for pomo.

# %%
[project.scripts]
???

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
# pomo start fails:
# AttributeError: 'Namespace' object has no attribute 'func'

# %% [markdown]
# **D2.**

# %%
# pomo stop when nothing is running raises ValueError but prints traceback

# %% [markdown]
# **D3.**

# %%
# Test pollutes ~/.pomo/pomo.db

# %% [markdown]
# **D4.**

# %%
# subprocess.run(['pomo', 'start'])  ← command not found

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Full main() with error handling and exit codes.

# %%
# Your code

# %% [markdown]
# **E2.** cmd_start, cmd_stop, cmd_list, cmd_report.

# %%
# Your code

# %% [markdown]
# **E3.** End-to-end pytest using subprocess + tmp_path.

# %%
# Your test

# %% [markdown]
# **E4.** README with quickstart for pomo.

# %%
# README.md

# %% [markdown]
# **E5.** GitHub Actions workflow for both lint + tests + coverage.

# %%
# .github/workflows/test.yml

# %% [markdown]
# **E6.** v0.1.0 tag + release.

# %%
# Commands

# %% [markdown]
# **E7.** A short demo script for the mentor Friday call.

# %%
# demo.sh

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
