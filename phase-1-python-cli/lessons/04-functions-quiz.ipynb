# %% [markdown]
# # Day 4 Quiz — Functions
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/04-functions-quiz.ipynb)
#
# > 🎯 **What this tests.** Function definitions, parameters vs arguments, defaults, keyword-only args, docstrings, return values, exceptions (`raise`, `try`/`except`), custom exception classes.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 28/35.
#
# ## Sections
#
# - **A** — MCQ (10)
# - **B** — Predict output (8)
# - **C** — Fill in (6)
# - **D** — Debug (4)
# - **E** — Write code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** What does `def` start?
#
# A) A class
# B) A function definition
# C) A variable
# D) A comment

# %% [markdown]
# **A2.** Difference between a parameter and an argument?
#
# A) Same thing, different word
# B) Parameter is in the def; argument is what's passed when calling
# C) Argument is in the def; parameter is what's passed
# D) Arguments are typed; parameters are not

# %% [markdown]
# **A3.** What does this function return? `def f(): pass`
#
# A) Nothing
# B) An error
# C) `None`
# D) `0`

# %% [markdown]
# **A4.** Which is dangerous?
#
# A) `def f(x=0):`
# B) `def f(x=None):`
# C) `def f(x=[]):`
# D) `def f(x=""):`

# %% [markdown]
# **A5.** What does the bare `*` in `def f(a, *, b, c):` do?
#
# A) Unpacks an iterable
# B) Means `b` and `c` must be passed by keyword
# C) Catches extra positional args
# D) Is a syntax error

# %% [markdown]
# **A6.** Where should the docstring go?
#
# A) Above the `def` line
# B) On the same line as `def`
# C) As the first statement inside the function
# D) Anywhere in the function

# %% [markdown]
# **A7.** When should you raise an exception vs return None?
#
# A) Always raise
# B) Always return None
# C) Raise when something abnormal happened; return None when 'not found' is a normal outcome
# D) Doesn't matter

# %% [markdown]
# **A8.** What's wrong with `except:` (bare except)?
#
# A) It catches all exceptions including KeyboardInterrupt and SystemExit
# B) It's slow
# C) It's not Python syntax
# D) Nothing is wrong

# %% [markdown]
# **A9.** Which lets you return multiple values?
#
# A) Python doesn't support multiple return
# B) `return a, b` (returns a tuple)
# C) `return [a, b]`
# D) Both B and C work, but B is more idiomatic

# %% [markdown]
# **A10.** What's the difference between `dict[key]` and `dict.get(key)`?
#
# A) Same thing
# B) `[key]` raises KeyError if missing; `.get(key)` returns None
# C) `[key]` returns None; `.get(key)` raises
# D) `.get(key)` is for nested keys

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
def add(a, b): return a + b
print(add(2, 3))

# %% [markdown]
# **B2.**

# %%
def greet(name, greeting='Hello'):
    return f'{greeting}, {name}!'
print(greet('Prince'))
print(greet('Prince', greeting='Hi'))

# %% [markdown]
# **B3.**

# %%
def f():
    pass
result = f()
print(result)

# %% [markdown]
# **B4.**

# %%
def make(items=[]):
    items.append(1)
    return items

print(make())
print(make())

# %% [markdown]
# **B5.**

# %%
def f(x):
    return x * 2
    print('hi')

print(f(5))

# %% [markdown]
# **B6.**

# %%
def divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return None

print(divide(10, 0))
print(divide(10, 2))

# %% [markdown]
# **B7.**

# %%
def f(*args):
    return sum(args)

print(f(1, 2, 3, 4))

# %% [markdown]
# **B8.**

# %%
def outer():
    x = 1
    def inner():
        return x + 1
    return inner()

print(outer())

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Define a function `is_even(n: int) -> bool` that returns True iff n is even.

# %%
# Your code

# %% [markdown]
# **C2.** Define `max_of(a: int, b: int) -> int` returning the larger.

# %%
# Your code

# %% [markdown]
# **C3.** Function `count_vowels(word: str) -> int` returning the count of vowels.

# %%
# Your code

# %% [markdown]
# **C4.** A function that returns both the average and the sum of a list of numbers, as a tuple.

# %%
def stats(nums: list[float]) -> tuple[float, float]:
    # Your code

# %% [markdown]
# **C5.** A function that takes a word entry dict and prints a one-line summary. Should NOT return anything.

# %%
WordEntry = dict[str, str]

def print_summary(entry: WordEntry) -> None:
    # Your code

# %% [markdown]
# **C6.** A function that takes a single required `word` and optional `pos` keyword arg (default 'unknown'). Returns a dict with both fields.

# %%
# Your code: make pos KEYWORD-ONLY using *

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
def add(a, b)
    return a + b

# %% [markdown]
# **D2.**

# %%
def greet(name):
return f'Hi {name}'

# %% [markdown]
# **D3.**

# %%
def find(items, target):
    for x in items:
        if x == target:
            return True
    return False

# Caller code:
result = find([1,2,3], 5)
if result:
    print('found')
else:
    print('not found')
# What if target=0 and items=[0,1,2]?

# %% [markdown]
# **D4.**

# %%
def divide(a, b):
    return a / b

result = divide(10, 0)
print(result)

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Write `lookup(words, target)` — searches the list for an entry whose `word` matches `target`. Returns the entry or None. Full type hints, docstring.

# %%
WordEntry = dict[str, str]
# Your code

# %% [markdown]
# **E2.** Write `strict_lookup` that raises `WordNotFoundError` if missing. Define the exception first.

# %%
# Your code

# %% [markdown]
# **E3.** Write `add_word(words, entry)` — appends `entry` to `words`. Raises `ValueError` if a duplicate (same `word`) already exists. Returns nothing.

# %%
# Your code

# %% [markdown]
# **E4.** Write `safe_parse_int(text, default=0)` — returns `int(text)` if possible, else `default`. Use try/except.

# %%
# Your code

# %% [markdown]
# **E5.** Write `quiz_loop(words, rounds=5)` — runs N rounds of pronunciation quiz. Uses `random.choice`, `input()`. Returns `(correct, total)` tuple. Track score.

# %%
import random
# Your code

# %% [markdown]
# **E6.** Write `card_summary(entry)` — returns a string like 'thorough (/ˈθʌrə/) — ละเอียด'. Format with f-string.

# %%
# Your code

# %% [markdown]
# **E7.** Write `validate_entry(entry)` — checks the dict has 'word', 'ipa', 'thai' keys, all non-empty strings. Raises ValueError with a clear message if not. Returns None.

# %%
# Your code

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# | Score | Meaning |
# |-------|---------|
# | 33–35 | Strong. |
# | 28–32 | Pass. |
# | 21–27 | Re-read [04-functions.ipynb](04-functions.ipynb). Retake. |
# | < 21  | Slow down. Functions are foundational. |
#
# Log score. Move to Day 5.
