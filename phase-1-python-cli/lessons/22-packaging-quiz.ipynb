# %% [markdown]
# # Day 22 Quiz — Packaging
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakkzz/prince-curriculum/blob/main/phase-1-python-cli/lessons/22-packaging-quiz.ipynb)
#
# > 🎯 **What this tests.** pyproject.toml entry points, uv tool install, semver, README, publishing.
#
# **Time:** 45–60 min. No AI tools.
# **Passing:** 24 / 35.
#
# ## Sections
#
# - **A** — Multiple choice (10)
# - **B** — Predict the output (8)
# - **C** — Fill in the missing code (6)
# - **D** — Find the bug (4)
# - **E** — Write the code, English Helper themed (7)
#
# > ✏️ **Student version.** Answers and explanations live in the mentor's notebook. Try every question; show your answers on the Friday call. Honest attempt beats lucky guess.

# %% [markdown]
# ## Section A — Multiple choice

# %% [markdown]
# **A1.** What does `[project.scripts]` in pyproject.toml do?

# %% [markdown]
# **A2.** What's `uv tool install`?

# %% [markdown]
# **A3.** What's semver?

# %% [markdown]
# **A4.** When to bump MAJOR version?

# %% [markdown]
# **A5.** Why MIT license for learning projects?

# %% [markdown]
# **A6.** Why `english-helper` for command but `english_helper` for module?

# %% [markdown]
# **A7.** Where does `uv tool install` put the CLI executable?

# %% [markdown]
# **A8.** PyPI: should you publish a generic name?

# %% [markdown]
# **A9.** `git tag v0.1.0` — what does that do?

# %% [markdown]
# **A10.** What's `[build-system]` in pyproject.toml?

# %% [markdown]
# ## Section B — Predict the output

# %% [markdown]
# **B1.**

# %%
# pyproject.toml has english-helper = 'english_helper.cli:main'
# After uv tool install:
# What happens on `english-helper add thorough`?

# %% [markdown]
# **B2.**

# %%
# Version is 0.1.0. You add a new optional flag. New version?

# %% [markdown]
# **B3.**

# %%
# Version 0.1.0. You change `add` to require a `--source` flag. Old `english-helper add thorough` no longer works.

# %% [markdown]
# **B4.**

# %%
# Version 0.1.0. You fix a typo in a docstring.

# %% [markdown]
# **B5.**

# %%
# uv tool install --from . english-helper
# Make code changes. Then `english-helper --version` shows old.

# %% [markdown]
# **B6.**

# %%
# Install with no PATH update:
# uv tool install --from . english-helper
# english-helper: command not found

# %% [markdown]
# **B7.**

# %%
# pyproject.toml:
# english-helper = 'english_helper.cli:main'
# But cli.py has `def Main():` (capital M).

# %% [markdown]
# **B8.**

# %%
# After uv tool install, uv tool list

# %% [markdown]
# ## Section C — Fill in the missing code

# %% [markdown]
# **C1.** Add a `[project.scripts]` section for `myapp`.

# %%
# pyproject.toml
[project]
name = 'myapp'
???

# %% [markdown]
# **C2.** Add basic project metadata.

# %%
[project]
???

# %% [markdown]
# **C3.** Configure hatch backend.

# %%
[build-system]
???
[tool.hatch.build.targets.wheel]
???

# %% [markdown]
# **C4.** Install your tool globally.

# %%
???

# %% [markdown]
# **C5.** Make a v0.1.0 git tag.

# %%
???

# %% [markdown]
# **C6.** Write a minimal README.md.

# %%
# README.md
???

# %% [markdown]
# ## Section D — Find the bug

# %% [markdown]
# **D1.**

# %%
# Installed but: english-helper: command not found

# %% [markdown]
# **D2.**

# %%
# english-helper runs old code after a fix

# %% [markdown]
# **D3.**

# %%
# pip install english-helper
# 'english-helper': command not found

# %% [markdown]
# **D4.**

# %%
# uv publish errors: "name already taken"

# %% [markdown]
# ## Section E — Write the code (English Helper themed)

# %% [markdown]
# **E1.** Full minimal pyproject.toml for english-helper.

# %%
# Your toml

# %% [markdown]
# **E2.** README.md with all required sections.

# %%
# Your README

# %% [markdown]
# **E3.** Verify installation locally.

# %%
# Commands you'd run

# %% [markdown]
# **E4.** Tag and push v0.1.0.

# %%
# Commands

# %% [markdown]
# **E5.** Add a `[project.optional-dependencies]` for dev tools.

# %%
# pyproject.toml
???

# %% [markdown]
# **E6.** A GitHub Actions workflow that builds and uploads to PyPI on tag push.

# %%
# .github/workflows/release.yml

# %% [markdown]
# **E7.** Write a CHANGELOG.md for v0.1.0.

# %%
# Your CHANGELOG

# %% [markdown]
# ## Score yourself
#
# - **A**: __ / 10
# - **B**: __ / 8
# - **C**: __ / 6
# - **D**: __ / 4
# - **E**: __ / 7
#
# **Total: __ / 35**
#
# Log your score in the learning log. 24+ to advance.
